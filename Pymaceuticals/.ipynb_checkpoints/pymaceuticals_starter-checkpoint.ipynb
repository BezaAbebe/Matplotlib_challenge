# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"] are the most impactful drug Regimen as they had the lowest total tumor volume
# - Tumor size reduces over time
# - Tumor volume increase as the mice weight increase

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results  
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merged_df = study_results.merge(right=mouse_metadata, how="left")

# Display the data table for preview
merged_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(merged_df["Mouse ID"].value_counts())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates = merged_df[merged_df.duplicated(subset=["Mouse ID", "Timepoint"], keep=False)]

# Getting unique Mouse IDs of these duplicates
unique_ids = duplicates['Mouse ID'].unique()
unique_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
merged_df[merged_df['Mouse ID'] == "g989"]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
duplicates_id = duplicates["Mouse ID"]
duplicates_id
clean_df = merged_df[merged_df["Mouse ID"].isin(duplicates_id) ==False]
clean_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_df["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
grouped_df = clean_df.groupby("Drug Regimen")
grouped_df.head()

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
mean = grouped_df["Tumor Volume (mm3)"].mean()
median = grouped_df["Tumor Volume (mm3)"].median()
variance = grouped_df["Tumor Volume (mm3)"].var()
str_dv = grouped_df["Tumor Volume (mm3)"].std()
str_err = grouped_df["Tumor Volume (mm3)"].sem()
str_err
# Assemble the resulting series into a single summary DataFrame.
summary_stat_df = pd.DataFrame({"Mean Tumor Volume": mean, 
                                "Median Tumor Volume": median, 
                                "Total Tumor Volume Variance": variance, 
                                "Tumor Volume Std. Dev.": str_dv, 
                                "Tumor Volume Std. Err.": str_err
})
summary_stat_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  \
# Drug Regimen
# Capomulin             40.675741            41.557809
# Ceftamin              52.591172            51.776157
# Infubinol             52.884795            51.820584
# Ketapril              55.235638            53.698743
# Naftisol              54.331565            52.509285
# Placebo               54.033581            52.288934
# Propriva              52.320930            50.446266
# Ramicane              40.216745            40.673236
# Stelasyn              54.233149            52.431737
# Zoniferol             53.236507            51.818479
#
#               Total Tumor Volume Variance  Tumor Volume Std. Dev.  \
# Drug Regimen
# Capomulin                       24.947764                4.994774
# Ceftamin                        39.290177                6.268188
# Infubinol                       43.128684                6.567243
# Ketapril                        68.553577                8.279709
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
summary_stat = clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].agg(mean="mean", median="median", var="var", std="std", sem="sem")
# Using the aggregation method, produce the same summary statistics in a single line
summary_stat
#the propriva value is not matching and i can't fi
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
total_num_row = grouped_df["Mouse ID"].count().reset_index()
desc_order = total_num_row.sort_values(by="Mouse ID", ascending=False)
desc_order

desc_order = desc_order.set_index("Drug Regimen")
desc_order

# Use DataFrame.plot() in order to create a bar chart of the data
desc_order.plot(kind="bar", legend=False)
plt.ylabel("# of Observed Mouse Timepoints")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
total_num_row = grouped_df["Mouse ID"].count().reset_index()
desc_order = total_num_row.sort_values(by="Mouse ID", ascending=False)
desc_order

# Set x axis and tick locations
x_axis = np.arange(len(desc_order))

trick_locations = [value for value in x_axis]
# Set y axis 
y_axis = desc_order["Mouse ID"]

#Plot bar chart
plt.bar(desc_order["Drug Regimen"], y_axis, align="center")
plt.xticks(trick_locations, desc_order["Drug Regimen"], rotation="vertical")

# Set a Title and labels
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mice_sex_dis = clean_df["Sex"].value_counts()
mice_sex_dis 
mice_sex_dis.plot(kind="pie", autopct="%.1f%%")
plt.ylabel("Sex")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
mice_sex_dis = clean_df["Sex"].value_counts().reset_index()
mice_sex_dis
plt.pie(mice_sex_dis["count"], labels=mice_sex_dis["Sex"], autopct="%.1f%%")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
filtered_df = clean_df[clean_df["Drug Regimen"].isin(regimens)]
filtered_df

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = filtered_df.groupby("Mouse ID")["Timepoint"].max().reset_index()
last_timepoint

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor_vol = pd.merge(last_timepoint, clean_df, on=["Mouse ID", "Timepoint"], how="left")
final_tumor_vol.head()

sorted_final_tumor_vol= final_tumor_vol.sort_values(by=['Tumor Volume (mm3)'], ascending=True)
sorted_final_tumor_vol
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 40     k403         45           22.050126                 1     Ramicane
# 70     s185         45           23.343598                 1    Capomulin
# 51     m601         45           28.430964                 1    Capomulin
# 90     x401         45           28.484033                 0    Capomulin
# 27     g791         45           29.128472                 1     Ramicane
# ..      ...        ...                 ...               ...          ...
# 43     l471         45           67.748662                 1     Ceftamin
# 0      a203         45           67.973419                 2    Infubinol
# 95     y769         45           68.594745                 4     Ceftamin
# 39     k210         45           68.923185                 3     Ceftamin
# 14     c139         45           72.226731                 2    Infubinol
#
#        Sex  Age_months  Weight (g)
# 40    Male          21          16
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for treatment in treatments:
    # print(treatment)
    final_vol_df = sorted_final_tumor_vol[sorted_final_tumor_vol["Drug Regimen"] == treatment]
    # print(final_vol_df)
    volumes = final_vol_df['Tumor Volume (mm3)']
    #print(volumes)
    
    tumor_vol_data.append(volumes)
    # print(tumor_vol_data)

    quartiles = final_vol_df['Tumor Volume (mm3)'].quantile([.25, .5, .75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    # print(f"{treatments} IQR: {iqr}")
    
    # # Locate the rows which contain mice on each drug and get the tumor volumes
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 *iqr)
    
    
    # Determine outliers using upper and lower bounds
    outliers = volumes[(volumes < lower_bound) | (volumes > upper_bound)]
   
    print(f"{treatment}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 15    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
red_circle = dict(markerfacecolor='r', marker='o') 
final_tumor_vol.boxplot(by='Drug Regimen', 
                        column='Tumor Volume (mm3)', 
                        grid=False,
                        flierprops=red_circle)
# Setting the title and labels
plt.title('')
plt.suptitle('')
plt.ylabel('Final Tumor Volume (mm3)')

# Show the plot
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
capomulin_df = filtered_df[filtered_df["Drug Regimen"] == "Capomulin"]

mouse_id = "l509"
mouse_data = capomulin_df[capomulin_df["Mouse ID"] == mouse_id]


plt.plot(mouse_data["Timepoint"], mouse_data["Tumor Volume (mm3)"])
plt.title(f"Capomulin Treatment of mouse l509")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
average_tumor_volume = capomulin_df.groupby('Mouse ID').agg(
    Average_Tumor_Volume=('Tumor Volume (mm3)', 'mean'),
    Weight=('Weight (g)', 'max') 
)

plt.scatter(average_tumor_volume['Weight'], average_tumor_volume['Average_Tumor_Volume'])
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
from scipy.stats import linregress

# y = mx + b
# y - average tumor volume
# m - the effect of Capomulin
# x - weight of mouse
# b - the standard effect of your weight to tumor volume

# x = 15
# m = ? - slope
# y = 36.18
# b = ? - intercept

weight = average_tumor_volume['Weight']
average_tumor_volume = average_tumor_volume['Average_Tumor_Volume']

(slope, intercept, correlation_value, pvalue, stderr) = linregress(weight, average_tumor_volume)
# print(slope)
# print(intercept)
print(f"The correlation between mouse weight and the average tumor volume is", correlation_value.round(2))

# y = mx + b
average_tumor_volume_eq_values = slope * weight + intercept

plt.scatter(weight , average_tumor_volume)
plt.plot(weight, average_tumor_volume_eq_values, "r-")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
